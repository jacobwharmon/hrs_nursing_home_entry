# %%
import pandas as pd

peek_df = pd.read_csv('../intermediate_data/all_columns/subset_1.csv')
# Out:
# C:\Users\jacob\AppData\Local\Temp\ipykernel_11524\4231675600.py:3: DtypeWarning: Columns (1504,1505,1506) have mixed types. Specify dtype option on import or set low_memory=False.
#   peek_df = pd.read_csv('../intermediate_data/all_columns/subset_1.csv')

# %%
variable_suffix = "age"
[col for col in peek_df.columns if variable_suffix in col]

# peek_df[['hhidpn','r2beda']]
# Out:
# ['s1dage_y',
#  's1dage_m',
#  's2dage_y',
#  's2dage_m',
#  's3dage_y',
#  's3dage_m',
#  's4dage_y',
#  's4dage_m',
#  's5dage_y',
#  's5dage_m',
#  's6dage_y',
#  's6dage_m',
#  's7dage_y',
#  's7dage_m',
#  's8dage_y',
#  's8dage_m',
#  's9dage_y',
#  's9dage_m',
#  's10dage_y',
#  's10dage_m',
#  's11dage_y',
#  's11dage_m',
#  's12dage_y',
#  's12dage_m',
#  's13dage_y',
#  's13dage_m',
#  's14dage_y',
#  's14dage_m',
#  's15dage_y',
#  's15dage_m',
#  'ragender',
#  'radage_m',
#  'radage_y',
#  'r1agem_b',
#  'r2agem_b',
#  'r3agem_b',
#  'r4agem_b',
#  'r5agem_b',
#  'r6agem_b',
#  'r7agem_b',
#  'r8agem_b',
#  'r9agem_b',
#  'r10agem_b',
#  'r11agem_b',
#  'r12agem_b',
#  'r13agem_b',
#  'r14agem_b',
#  'r15agem_b',
#  'r1agem_e',
#  'r2agem_e',
#  'r3agem_e',
#  'r4agem_e',
#  'r5agem_e',
#  'r6agem_e',
#  'r7agem_e',
#  'r8agem_e',
#  'r9agem_e',
#  'r10agem_e',
#  'r11agem_e',
#  'r12agem_e',
#  'r13agem_e',
#  'r14agem_e',
#  'r15agem_e',
#  'r1agem_m',
#  'r2agem_m',
# ...
